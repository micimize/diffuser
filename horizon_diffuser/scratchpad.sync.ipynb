# %%
from typing import Final, Iterable, List, Optional, Sequence, Tuple
from minigrid_maze_env import BitMaze, MiniGridMazeEnv, example_maze, random_maze
import PIL
from IPython import display

import numpy as np

image: Final = PIL.Image.fromarray

complexity_space: List[float] = list(np.arange(0.0, 1.1, 0.25))
density_space: List[float] = list(np.arange(0.0, 1.1, 0.25))
width = 20
height = 20


def sample_mazes(complexities: Sequence[float], densitiies: Sequence[float]) -> Iterable[BitMaze]:
    for complexity in complexities:
        for density in densitiies:
            print(f"complexity {complexity} density {density}")
            yield random_maze(50, 50, complexity, density)


env = MiniGridMazeEnv(random_maze(50, 50, 0, 0), minimum_goal_distance=5, render_mode="rgb_array")

for maze in sample_mazes(complexity_space, density_space):
    env.bit_maze = maze
    obs, _ = env.reset()
    display.display(image(env.render()))
# Out:
# complexity 0.0 density 0.0
# placing 200 wall blocks
# goal placed at None, agent placed at (1, 31)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.0 density 0.25
# placing 318 wall blocks
# goal placed at None, agent placed at (38, 28)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.0 density 0.5
# placing 413 wall blocks
# goal placed at None, agent placed at (39, 5)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.0 density 0.75
# placing 492 wall blocks
# goal placed at None, agent placed at (32, 3)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.0 density 1.0
# placing 545 wall blocks
# goal placed at None, agent placed at (24, 1)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.25 density 0.0
# placing 200 wall blocks
# goal placed at None, agent placed at (19, 48)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.25 density 0.25
# placing 1298 wall blocks
# goal placed at None, agent placed at (9, 34)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.25 density 0.5
# placing 1321 wall blocks
# goal placed at None, agent placed at (3, 15)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.25 density 0.75
# placing 1324 wall blocks
# goal placed at None, agent placed at (8, 19)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.25 density 1.0
# placing 1328 wall blocks
# goal placed at None, agent placed at (27, 43)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.5 density 0.0
# placing 200 wall blocks
# goal placed at None, agent placed at (6, 11)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.5 density 0.25
# placing 1291 wall blocks
# goal placed at None, agent placed at (6, 1)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.5 density 0.5
# placing 1321 wall blocks
# goal placed at None, agent placed at (3, 46)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.5 density 0.75
# placing 1323 wall blocks
# goal placed at None, agent placed at (1, 22)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.5 density 1.0
# placing 1323 wall blocks
# goal placed at None, agent placed at (40, 43)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.75 density 0.0
# placing 200 wall blocks
# goal placed at None, agent placed at (15, 41)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.75 density 0.25
# placing 1287 wall blocks
# goal placed at None, agent placed at (27, 40)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.75 density 0.5
# placing 1305 wall blocks
# goal placed at None, agent placed at (21, 13)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.75 density 0.75
# placing 1329 wall blocks
# goal placed at None, agent placed at (29, 3)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 0.75 density 1.0
# placing 1324 wall blocks
# goal placed at None, agent placed at (24, 9)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 1.0 density 0.0
# placing 200 wall blocks
# goal placed at None, agent placed at (2, 7)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 1.0 density 0.25
# placing 1311 wall blocks
# goal placed at None, agent placed at (37, 1)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 1.0 density 0.5
# placing 1319 wall blocks
# goal placed at None, agent placed at (9, 28)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 1.0 density 0.75
# placing 1326 wall blocks
# goal placed at None, agent placed at (44, 1)
# <PIL.Image.Image image mode=RGB size=1632x1632>
# complexity 1.0 density 1.0
# placing 1322 wall blocks
# goal placed at None, agent placed at (2, 9)
# <PIL.Image.Image image mode=RGB size=1632x1632>
